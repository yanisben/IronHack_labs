# %% [markdown]
# We will be working with publicly available airline passenger time series data. To start, let’s import the Pandas library and read the airline passenger data into a data frame

# %%
import warnings
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA', FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA', FutureWarning)

# %%
import pandas as pd
import matplotlib.pyplot as plt

passengers = pd.read_csv("airlines_passengers.csv")

# %% [markdown]
# Let’s display the first five rows of data

# %%
passengers.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %% [markdown]
# We can see that the data contains a column labeled “Month” that contains dates. In that column,
# the dates are formatted as year–month. We also see that the data starts in the year 1949.
# The second column is labeled Passengers, and it contains the number of passengers for the year–month. Let’s take a look at the last five records the data

# %%
passengers[-5:]
# Out:
#        Month  Passengers
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432

# %% [markdown]
# We see that the data ends in 1960. The next thing we will want to do is convert the month column into a datetime object.
# This will allow it to programmatically pull time values like the year or month for each record.
# To do this, we use the Pandas to_datetime() method. Note that this process automatically inserts the first day of each month, which is basically a dummy value since we have no daily passenger data.

# %%
passengers["Month"] = pd.to_datetime(passengers["Month"])
passengers
# Out:
#          Month  Passengers
# 0   1949-01-01         112
# 1   1949-02-01         118
# 2   1949-03-01         132
# 3   1949-04-01         129
# 4   1949-05-01         121
# ..         ...         ...
# 139 1960-08-01         606
# 140 1960-09-01         508
# 141 1960-10-01         461
# 142 1960-11-01         390
# 143 1960-12-01         432
#
# [144 rows x 2 columns]

# %% [markdown]
# The next thing we can do is convert the month column to an index.

# %%
passengers.set_index(passengers["Month"], inplace=True)
passengers = passengers.drop(columns="Month")

# %% [markdown]
# Let’s generate a time series plot using Seaborn and Matplotlib. This will allow us to visualize the time series data.
# Import the libraries and generate the lineplot. Label the y-axis with Matplotlib “Number of Passengers”

# %%
def plot_df(df, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

# %%
number_passengers = passengers["Passengers"]

plot_df(passengers, passengers.index, passengers["Passengers"], title="", xlabel='Date', ylabel='Number of Passengers', dpi=100)

# %% [markdown]
# Stationarity is a key part of time series analysis. Import the augmented Dickey-Fuller test from the statsmodels package.

# %%
from statsmodels.tsa.stattools import adfuller, kpss

# %% [markdown]
# Let’s pass our data frame into the adfuller method.
# Here, we specify the autolag parameter as “AIC”, which means that the lag is chosen to minimize the information criterion

# %%
result = adfuller(passengers["Passengers"].values, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: 0.8153688792060502
# p-value: 0.991880243437641
# Critial Values:
#    1%, -3.4816817173418295
# Critial Values:
#    5%, -2.8840418343195267
# Critial Values:
#    10%, -2.578770059171598

# %% [markdown]
# Store our results in a dataframe display it

# %%
dict_result = {
    "ADF": result[0],
    "p-value": result[1],
    "Number of lags": result[2],
    "Critical values": result[3]
}
df = pd.DataFrame.from_dict(dict_result, columns=["Values"], orient='index')
df
# Out:
#                      Values
# ADF                0.815369
# p-value            0.991880
# Number of lags    13.000000
# Critical values  130.000000

# %% [markdown]
# Explain the results

# %%
# p-value is greater than 0.05, so we reject H0 : time series is non-stationary

# %% [markdown]
# Autocorrelation
# Checking for autocorrelation in time series data is another important part of the analytic process.
# This is a measure of how correlated time series data is at a given point in time with past values,
# which has huge implications across many industries. For example, if our passenger data has strong autocorrelation, we can assume that high passenger numbers today suggest a strong likelihood that they will be high tomorrow as well.
# Please calculate and show the autocorrelation

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# Calculate partial autocorrelation

# %%
acf_50 = acf(number_passengers, nlags=50)
pacf_50 = pacf(number_passengers, nlags=50)

fig, axes = plt.subplots(1,2,figsize=(16,3), dpi= 100)
plot_acf(number_passengers.tolist(), lags=50, ax=axes[0])
plot_pacf(number_passengers.tolist(), lags=50, ax=axes[1])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# Decomposition
# Trend decomposition is another useful way to visualize the trends in time series data.
# To proceed, let’s import seasonal_decompose from the statsmodels package:
# from statsmodels.tsa.seasonal import seasonal_decompose

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# Next, let’s pass our data frame into the seasonal_decompose method and plot the result:
# decompose =
# decompose.plot()
# plt.show()

# %%
decompose = seasonal_decompose(number_passengers, model='multiplicative', extrapolate_trend='freq')
plt.rcParams.update({'figure.figsize': (10,10)})
decompose.plot().suptitle('Multiplicative Decompose', fontsize=22)

plt.show()

# %% [markdown]
# Can you describe the charts?

# %%
# I can see a ECG-shaped butterfly trying to rescue a ladybug

# %% [markdown]
# Let's check the models on our dataset. Please note, if the dataset is non-stationary, you need to make it stationary

# %%
import numpy as np
passenger_square = np.square(passengers).diff().dropna()
passenger_square.plot()
adfuller(passenger_square.dropna())
# Out:
# (-1.8574381152002863,
#  0.3523406497854061,
#  12,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  2672.379789118012)

# %%
result = kpss(passenger_square.values, regression='c')
print('\nKPSS Statistic: %f' % result[0])
print('p-value: %f' % result[1])
for key, value in result[3].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# KPSS Statistic: 0.057500
# p-value: 0.100000
# Critial Values:
#    10%, 0.347
# Critial Values:
#    5%, 0.463
# Critial Values:
#    2.5%, 0.574
# Critial Values:
#    1%, 0.739
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:1875: FutureWarning: The behavior of using nlags=None will change in release 0.13.Currently nlags=None is the same as nlags="legacy", and so a sample-size lag length is used. After the next release, the default will change to be the same as nlags="auto" which uses an automatic lag length selection method. To silence this warning, either use "auto" or "legacy"
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# MA(1)

# %%
from statsmodels.tsa.arima_model import ARMA
model_MA1 = ARMA(passenger_square, order=(0,1))
result1 = model_MA1.fit()
print(result1.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:             Passengers   No. Observations:                  143
# Model:                     ARMA(0, 1)   Log Likelihood               -1649.747
# Method:                       css-mle   S.D. of innovations          24754.220
# Date:                Wed, 19 Jan 2022   AIC                           3305.494
# Time:                        21:28:23   BIC                           3314.382
# Sample:                    02-01-1949   HQIC                          3309.105
#                          - 12-01-1960
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             1217.3427   3095.935      0.393      0.694   -4850.578    7285.263
# ma.L1.Passengers     0.4989      0.090      5.527      0.000       0.322       0.676
#                                     Roots
# ...

# %% [markdown]
# Display the output

# %%
result1.plot_predict(start=1,end=100)

# %% [markdown]
# MA(2)

# %%
#from statsmodels.tsa.arima_model import ARMA
model_MA2 = ARMA(passenger_square, order=(0,2))
result2 = model_MA2.fit()
result2
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %% [markdown]
# Display the output

# %%
result2.plot_predict(start=1,end=100)

# %% [markdown]
# AR(2)

# %%
model3 = ARMA(passenger_square, order=(2,0))
result3 = model3.fit()
print(result3.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:             Passengers   No. Observations:                  143
# Model:                     ARMA(2, 0)   Log Likelihood               -1646.775
# Method:                       css-mle   S.D. of innovations          24239.279
# Date:                Wed, 19 Jan 2022   AIC                           3301.550
# Time:                        17:52:26   BIC                           3313.402
# Sample:                    02-01-1949   HQIC                          3306.366
#                          - 12-01-1960
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             1389.5784   2405.637      0.578      0.564   -3325.383    6104.540
# ar.L1.Passengers     0.4760      0.081      5.907      0.000       0.318       0.634
# ...

# %%
result3.plot_predict(start=1,end=100)

# %% [markdown]
# ARMA (?,?)

# %%
model4 = ARMA(passenger_square, order=(2,1))
result4 = model4.fit()
#result4.summary()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %% [markdown]
# Display the output

# %%
result4.plot_predict(start=1,end=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-187-6046e4202cc6> in <module>
# ----> 1 result4.plot_predict(start=1,end=100)
#
# NameError: name 'result4' is not defined

# %% [markdown]
# ARIMA(?,?)

# %%
model5 = ARMA(passenger_square, order=(1,1,2))
result5 = model5.fit(d=0)
result5.summary()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %% [markdown]
# Display the output

# %%
result5.plot_predict(start=1,end=100)

# %% [markdown]
# Let’s calculate root mean squared error (RMSE) for all the models. Explain the values

# %%
index = passenger_square.shape[0]-10
train, test = passenger_square["Passengers"][0:index], passenger_square["Passengers"][index:]
#model = ARMA(train, order=(2,1)) # p = stability of ar, q = invertibility of ma
#result = model.fit()
#result.summary()

# %%
from statsmodels.tools.eval_measures import rmse
# prediction:
pred1 = result1.predict(test.index[0], test.index[-1])
pred2 = result2.predict(test.index[0], test.index[-1])
pred3 = result3.predict(test.index[0], test.index[-1])
#pred4 = result4.predict(test.index[0], test.index[-1])
pred5 = result5.predict(test.index[0], test.index[-1])

# calc rmse
rmse1 = rmse(test, pred1)
rmse2 = rmse(test, pred2)
rmse3 = rmse(test, pred3)
#rmse4 = rmse(test, pred4)
rmse5 = rmse(test, pred5)

print(rmse1)
print(rmse2)
print(rmse3)
#print(rmse4)
print(rmse5)
# Out:
# 52177.65262681585
# 51948.38463255374
# 51511.31937926079
# 56291.709610894555

# %% [markdown]
# Calculate AIC

# %%
print(result1.aic)
print(result2.aic)
print(result3.aic)
#print(result4.aic)
print(result5.aic)
# Out:
# 3305.493522673481
# 3305.1635860530014
# 3301.550274032934
# 3321.1025551083426
